# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import num

# %%
dataframe=pd.read_csv('/u/dssc/acesa000/STL-Reacher/outputs/output/train/logs/rewards.csv')

# %%
print(dataframe[(dataframe['Environment']==11)&(dataframe['Episode']==13)])
# Out:
#         Environment  Episode  Step    Reward
# 156323           11       13     0 -0.110316
# 156335           11       13     1 -0.104667
# 156347           11       13     2 -0.090964
# 156359           11       13     3 -0.090964
# 156371           11       13     4 -0.089565
# ...             ...      ...   ...       ...
# 168287           11       13   997 -0.015363
# 168299           11       13   998 -0.015363
# 168311           11       13   999 -0.015363
# 168323           11       13  1000 -0.015363
# 168335           11       13  1001 -0.015363
#
# [1002 rows x 4 columns]

# %%
print(df)
# Out:
# Total_Episode
# 0        0.025621
# 1       -0.001272
# 2        0.051466
# 3        0.000313
# 4        0.006988
#            ...
# 36262    0.072318
# 36274    0.072484
# 36286    0.072484
# 36298    0.072484
# 36310    0.072484
# Name: Robustness, Length: 35314, dtype: float64

# %%
plt.plot(df)
